# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import pandas as pd
import scipy
from scipy.optimize import curve_fit
plt.rc('xtick',labelsize=20); plt.rc('ytick',labelsize=20)
plt.rcParams['figure.figsize'] = (14,8)

# %%
ax = plt.axes()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(2));
ax.yaxis.set_minor_locator(ticker.MultipleLocator(1));

V4=np.array([0,8,16,19,23,24,32,38,39,40,44,48,56,64,72,80])
I4=np.array([0,5,10,11,6,7,15,19,18,17,16,15,21,24,25,28])

V6=np.array([0,8,16,20,22,24,25,32,38,40,43,47,48,56,64,72,80])
I6=np.array([0,4,9,10,9,4.5,4,11,14,15,12,11.3,11,16,18,17,19])

V8=np.array([0,8,16,20,23,24,26,32,38,40,44,48,49,56,64,72,80])
I8=np.array([0,2,8,10,6,3,1,7,11.5,12,9,7.5,7,10,11.5,11,13])

plt.title('Зависимости $I_k = f(V_2)$', size=20)
plt.xlabel('V, B',size=20)
plt.ylabel('I, мкА',size=20)

plt.plot(V4,I4,'o-', color='blue', label='$V_2 = 4 B$')
plt.plot(V6,I6,'o-', color='red', label='$V_2 = 6 B$')
plt.plot(V8,I8,'o-', color='green', label='$V_2 = 8 B$')
plt.grid()
plt.legend(fontsize='16',loc='upper left')
